# %% [markdown]
# ## Exporting the results to PDF
#
# Once you complete the assignments, export the entire notebook as PDF and attach it to your homework solutions.
# The best way of doing that is
# 1. Run all the cells of the notebook.
# 2. Export/download the notebook as PDF (File -> Download as -> PDF via LaTeX (.pdf)).
# 3. Concatenate your solutions for other tasks with the output of Step 2. On linux, you can use `pdfunite`, there are similar tools for other platforms, too. You can only upload a single PDF file to Moodle.
#
# Make sure you are using `nbconvert` version 5.5 or later by running `jupyter nbconvert --version`. Older versions clip lines that exceed page width, which makes your code harder to grade.

# %% [markdown]
# # Matrix Factorization

# %%
import time
import scipy.sparse as sp
import numpy as np
from scipy.sparse.linalg import svds
from sklearn.linear_model import Ridge

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Restaurant recommendation
#
# The goal of this task is to recommend restaurants to users based on the rating data in the Yelp dataset. For this, we try to predict the rating a user will give to a restaurant they have not yet rated based on a latent factor model.
#
# Specifically, the objective function (loss) we wanted to optimize is:
# $$
# \mathcal{L} = \min_{P, Q} \sum_{(u, i) \in S} (R_{ui} - \mathbf{q}_u\mathbf{p}_i^T)^2 + \lambda\sum_i{\left\lVert \mathbf{p}_i  \right\rVert}^2 + \lambda\sum_u {\left\lVert\mathbf{q}_u  \right\rVert}^2
# $$
#
# where $S$ is the set of $(u, i)$ pairs for which the rating $R_{ui}$ given by user $u$ to restaurant $i$ is known. Here we have also introduced two regularization terms to help us with overfitting where $\lambda$ is hyper-parameter that control the strength of the regularization.
#
# The task it to solve the matrix factorization via alternating least squares _and_ stochastic gradient descent (non-batched, you may omit the bias).
#
# **Hint 1**: Using the closed form solution for regression might lead to singular values. To avoid this issue perform the regression step with an existing package such as scikit-learn. It is advisable to use ridge regression to account for regularization.
#
# **Hint 2**: If you are using the scikit-learn package remember to set ``fit_intercept = False`` to only learn the coefficients of the linear regression.

# %% [markdown]
# ### Load and Preprocess the Data (nothing to do here)

# %%
ratings = np.load("exercise_11_matrix_factorization_ratings.npy")

# %%
# We have triplets of (user, restaurant, rating).
ratings
# Out:
# array([[101968,   1880,      1],
#        [101968,    284,      5],
#        [101968,   1378,      2],
#        ...,
#        [ 72452,   2100,      4],
#        [ 72452,   2050,      5],
#        [ 74861,   3979,      5]])

# %% [markdown]
# Now we transform the data into a matrix of dimension [N, D], where N is the number of users and D is the number of restaurants in the dataset. We store the data as a sparse matrix to avoid out-of-memory issues.

# %%
n_users = np.max(ratings[:,0] + 1)
n_restaurants = np.max(ratings[:,1] + 1)
R = sp.coo_matrix((ratings[:,2], (ratings[:,0], ratings[:,1])), shape=(n_users, n_restaurants)).tocsr()
R
# Out:
# <337867x5899 sparse matrix of type '<class 'numpy.int64'>'
# 	with 929606 stored elements in Compressed Sparse Row format>

# %% [markdown]
# To avoid the <a href="https://en.wikipedia.org/wiki/Cold_start_(computing)"> cold start problem</a>, in the preprocessing step, we recursively remove all users and restaurants with 10 or less ratings.
#
# Then, we randomly select 200 data points for the validation and test sets, respectively.
#
# After this, we subtract the mean rating for each users to account for this global effect.
#
# **Note**: Some entries might become zero in this process -- but these entries are different than the 'unknown' zeros in the matrix. We store the indices for which we the rating data available in a separate variable.

# %%
def cold_start_preprocessing(matrix, min_entries):
    """
    Recursively removes rows and columns from the input matrix which have less than min_entries nonzero entries.
    
    Parameters
    ----------
    matrix      : sp.spmatrix, shape [N, D]
                  The input matrix to be preprocessed.
    min_entries : int
                  Minimum number of nonzero elements per row and column.

    Returns
    -------
    matrix      : sp.spmatrix, shape [N', D']
                  The pre-processed matrix, where N' <= N and D' <= D
        
    """
    print("Shape before: {}".format(matrix.shape))
    
    shape = (-1, -1)
    while matrix.shape != shape:
        shape = matrix.shape
        nnz = matrix > 0
        row_ixs = nnz.sum(1).A1 > min_entries
        matrix = matrix[row_ixs]
        nnz = matrix > 0
        col_ixs = nnz.sum(0).A1 > min_entries
        matrix = matrix[:, col_ixs]
    print("Shape after: {}".format(matrix.shape))
    nnz = matrix>0
    assert (nnz.sum(0).A1 > min_entries).all()
    assert (nnz.sum(1).A1 > min_entries).all()
    return matrix

# %% [markdown]
# ### Task 1: Implement a function that subtracts the mean user rating from the sparse rating matrix

# %%
def shift_user_mean(matrix):
    """
    Subtract the mean rating per user from the non-zero elements in the input matrix.
    
    Parameters
    ----------
    matrix : sp.spmatrix, shape [N, D]
             Input sparse matrix.
    Returns
    -------
    matrix : sp.spmatrix, shape [N, D]
             The modified input matrix.
    
    user_means : np.array, shape [N, 1]
                 The mean rating per user that can be used to recover the absolute ratings from the mean-shifted ones.

    """
    
    # TODO: Compute the modified matrix and user_means
    
    ## BEGIN SOLUTION

    ## END SOLUTION
    
    assert np.all(np.isclose(matrix.mean(1), 0))
    return matrix, user_means

# %% [markdown]
# ### Split the data into a train, validation and test set (nothing to do here)

# %%
def split_data(matrix, n_validation, n_test):
    """
    Extract validation and test entries from the input matrix. 
    
    Parameters
    ----------
    matrix          : sp.spmatrix, shape [N, D]
                      The input data matrix.
    n_validation    : int
                      The number of validation entries to extract.
    n_test          : int
                      The number of test entries to extract.

    Returns
    -------
    matrix_split    : sp.spmatrix, shape [N, D]
                      A copy of the input matrix in which the validation and test entries have been set to zero.
    
    val_idx         : tuple, shape [2, n_validation]
                      The indices of the validation entries.
    
    test_idx        : tuple, shape [2, n_test]
                      The indices of the test entries.
    
    val_values      : np.array, shape [n_validation, ]
                      The values of the input matrix at the validation indices.
                      
    test_values     : np.array, shape [n_test, ]
                      The values of the input matrix at the test indices.

    """
    
    matrix_cp = matrix.copy()
    non_zero_idx = np.argwhere(matrix_cp)
    ixs = np.random.permutation(non_zero_idx)
    val_idx = tuple(ixs[:n_validation].T)
    test_idx = tuple(ixs[n_validation:n_validation + n_test].T)
    
    val_values = matrix_cp[val_idx].A1
    test_values = matrix_cp[test_idx].A1
    
    matrix_cp[val_idx] = matrix_cp[test_idx] = 0
    matrix_cp.eliminate_zeros()

    return matrix_cp, val_idx, test_idx, val_values, test_values

# %%
R = cold_start_preprocessing(R, 20)
# Out:
# Shape before: (337867, 5899)
# Shape after: (3529, 2072)

# %%
n_validation = 200
n_test = 200
# Split data
R_train, val_idx, test_idx, val_values, test_values = split_data(R, n_validation, n_test)

# %%
# Remove user means.
nonzero_indices = np.argwhere(R_train)
R_shifted, user_means = shift_user_mean(R_train)
# Apply the same shift to the validation and test data.
val_values_shifted = val_values - user_means[np.array(val_idx).T[:,0]].A1
test_values_shifted = test_values - user_means[np.array(test_idx).T[:,0]].A1

# %% [markdown]
# ### Compute the loss function (nothing to do here)

# %%
def loss(values, ixs, Q, P, reg_lambda):
    """
    Compute the loss of the latent factor model (at indices ixs).
    Parameters
    ----------
    values : np.array, shape [n_ixs,]
        The array with the ground-truth values.
    ixs : tuple, shape [2, n_ixs]
        The indices at which we want to evaluate the loss (usually the nonzero indices of the unshifted data matrix).
    Q : np.array, shape [N, k]
        The matrix Q of a latent factor model.
    P : np.array, shape [k, D]
        The matrix P of a latent factor model.
    reg_lambda : float
        The regularization strength
          
    Returns
    -------
    loss : float
           The loss of the latent factor model.

    """
    mean_sse_loss = np.sum((values - Q.dot(P)[ixs])**2)
    regularization_loss =  reg_lambda * (np.sum(np.linalg.norm(P, axis=0)**2) + np.sum(np.linalg.norm(Q, axis=1) ** 2))
    
    return mean_sse_loss + regularization_loss

# %% [markdown]
# ## Alternating optimization
#
# In the first step, we will approach the problem via alternating optimization, as learned in the lecture. That is, during each iteration you first update $Q$ while having $P$ fixed and then vice versa.

# %% [markdown]
# ### Task 2: Implement a function that initializes the latent factors $Q$ and $P$

# %%
def initialize_Q_P(matrix, k, init='random'):
    """
    Initialize the matrices Q and P for a latent factor model.
    
    Parameters
    ----------
    matrix : sp.spmatrix, shape [N, D]
             The matrix to be factorized.
    k      : int
             The number of latent dimensions.
    init   : str in ['svd', 'random'], default: 'random'
             The initialization strategy. 'svd' means that we use SVD to initialize P and Q, 
             'random' means we initialize the entries in P and Q randomly in the interval [0, 1).

    Returns
    -------
    Q : np.array, shape [N, k]
        The initialized matrix Q of a latent factor model.

    P : np.array, shape [k, D]
        The initialized matrix P of a latent factor model.
    """
    np.random.seed(0)
    
    # TODO: Compute Q and P
    
    ## BEGIN SOLUTION

    ## END SOLUTION
        
    assert Q.shape == (matrix.shape[0], k)
    assert P.shape == (k, matrix.shape[1])
    return Q, P

# %% [markdown]
# ### Task 3: Implement the alternating optimization approach and stochastic gradient approach

# %%
def latent_factor_alternating_optimization(R, non_zero_idx, k, val_idx, val_values,
                                           reg_lambda, max_steps=100, init='random',
                                           log_every=1, patience=5, eval_every=1, optimizer='sgd', lr=1e-2):
    """
    Perform matrix factorization using alternating optimization. Training is done via patience,
    i.e. we stop training after we observe no improvement on the validation loss for a certain
    amount of training steps. We then return the best values for Q and P oberved during training.
    
    Parameters
    ----------
    R                 : sp.spmatrix, shape [N, D]
                        The input matrix to be factorized.
                      
    non_zero_idx      : np.array, shape [nnz, 2]
                        The indices of the non-zero entries of the un-shifted matrix to be factorized. 
                        nnz refers to the number of non-zero entries. Note that this may be different
                        from the number of non-zero entries in the input matrix M, e.g. in the case
                        that all ratings by a user have the same value.
    
    k                 : int
                        The latent factor dimension.
    
    val_idx           : tuple, shape [2, n_validation]
                        Tuple of the validation set indices.
                        n_validation refers to the size of the validation set.
                      
    val_values        : np.array, shape [n_validation, ]
                        The values in the validation set.
                      
    reg_lambda        : float
                        The regularization strength.
                      
    max_steps         : int, optional, default: 100
                        Maximum number of training steps. Note that we will stop early if we observe
                        no improvement on the validation error for a specified number of steps
                        (see "patience" for details).
                      
    init              : str in ['random', 'svd'], default 'random'
                        The initialization strategy for P and Q. See function initialize_Q_P for details.
    
    log_every         : int, optional, default: 1
                        Log the training status every X iterations.
                    
    patience          : int, optional, default: 5
                        Stop training after we observe no improvement of the validation loss for X evaluation
                        iterations (see eval_every for details). After we stop training, we restore the best 
                        observed values for Q and P (based on the validation loss) and return them.
                      
    eval_every        : int, optional, default: 1
                        Evaluate the training and validation loss every X steps. If we observe no improvement
                        of the validation error, we decrease our patience by 1, else we reset it to *patience*.
                        
    optimizer         : str, optional, default: sgd
                        If `sgd` stochastic gradient descent shall be used. Otherwise, use alternating least squares.

    Returns
    -------
    best_Q            : np.array, shape [N, k]
                        Best value for Q (based on validation loss) observed during training
                      
    best_P            : np.array, shape [k, D]
                        Best value for P (based on validation loss) observed during training
                      
    validation_losses : list of floats
                        Validation loss for every evaluation iteration, can be used for plotting the validation
                        loss over time.
                        
    train_losses      : list of floats
                        Training loss for every evaluation iteration, can be used for plotting the training
                        loss over time.                     
    
    converged_after   : int
                        it - patience*eval_every, where it is the iteration in which patience hits 0,
                        or -1 if we hit max_steps before converging. 

    """
    
    # TODO: Compute best_Q, best_P, validation_losses, train_losses and converged_after
 
    ## BEGIN SOLUTION
   
    ## END SOLUTION
    
    return best_Q, best_P, validation_losses, train_losses, converged_after

# %% [markdown]
# ### Train the latent factor (nothing to do here)

# %%
Q_sgd, P_sgd, val_loss_sgd, train_loss_sgd, converged_sgd = latent_factor_alternating_optimization(
    R_shifted, nonzero_indices, k=100, val_idx=val_idx, val_values=val_values_shifted, 
    reg_lambda=1e-4, init='random', max_steps=100, patience=10, optimizer='sgd', lr=1e-2
)
# Out:
# Iteration 0, training loss: 96804865.847, validation loss: 125029.703
# Iteration 1, training loss: 287580.429, validation loss: 620.547
# Iteration 2, training loss: 164611.728, validation loss: 518.469
# Iteration 3, training loss: 113535.685, validation loss: 489.704
# Iteration 4, training loss: 84477.437, validation loss: 470.566
# Iteration 5, training loss: 65036.610, validation loss: 464.640
# Iteration 6, training loss: 51687.799, validation loss: 470.806
# Iteration 7, training loss: 41796.322, validation loss: 470.562
# Iteration 8, training loss: 34171.781, validation loss: 479.404
# Iteration 9, training loss: 28487.833, validation loss: 487.408
# Iteration 10, training loss: 23805.719, validation loss: 492.171
# Iteration 11, training loss: 20095.304, validation loss: 497.112
# Iteration 12, training loss: 17139.779, validation loss: 503.008
# Iteration 13, training loss: 14754.154, validation loss: 510.140
# Iteration 14, training loss: 12786.743, validation loss: 511.673
# Converged after 5 iterations, on average 7.097s per iteration

# %%
Q_als, P_als, val_loss_als, train_loss_als, converged_als = latent_factor_alternating_optimization(
    R_shifted, nonzero_indices, k=100, val_idx=val_idx, val_values=val_values_shifted, 
    reg_lambda=1e-4, init='random', max_steps=100, patience=10, optimizer='als'
)
# Out:
# Iteration 0, training loss: 96804865.847, validation loss: 125029.703
# Iteration 1, training loss: 2212.730, validation loss: 1334.392
# Iteration 2, training loss: 510.023, validation loss: 806.701
# Iteration 3, training loss: 196.702, validation loss: 763.065
# Iteration 4, training loss: 96.920, validation loss: 755.414
# Iteration 5, training loss: 55.411, validation loss: 732.651
# Iteration 6, training loss: 35.201, validation loss: 702.033
# Iteration 7, training loss: 24.470, validation loss: 692.316
# Iteration 8, training loss: 18.350, validation loss: 684.021
# Iteration 9, training loss: 14.674, validation loss: 676.930
# Iteration 10, training loss: 12.376, validation loss: 666.381
# Iteration 11, training loss: 10.889, validation loss: 658.312
# Iteration 12, training loss: 9.907, validation loss: 654.999
# Iteration 13, training loss: 9.239, validation loss: 653.876
# Iteration 14, training loss: 8.773, validation loss: 652.892
# Iteration 15, training loss: 8.441, validation loss: 652.602
# Iteration 16, training loss: 8.200, validation loss: 653.609
# Iteration 17, training loss: 8.022, validation loss: 655.562
# Iteration 18, training loss: 7.886, validation loss: 657.055
# Iteration 19, training loss: 7.780, validation loss: 659.627
# Iteration 20, training loss: 7.695, validation loss: 661.086
# Iteration 21, training loss: 7.625, validation loss: 662.949
# Iteration 22, training loss: 7.565, validation loss: 663.061
# Iteration 23, training loss: 7.514, validation loss: 664.435
# Iteration 24, training loss: 7.470, validation loss: 663.083
# Converged after 15 iterations, on average 4.920s per iteration

# %% [markdown]
# ### Plot the validation and training losses over for each iteration (nothing to do here)

# %%
fig, ax = plt.subplots(1, 2, figsize=[10, 5])
fig.suptitle("Alternating optimization, k=100")

ax[0].plot(train_loss_sgd[1::], label='sgd')
ax[0].plot(train_loss_als[1::], label='als')
ax[0].set_title('Training loss')
ax[0].set_xlabel("Training iteration")
ax[0].set_ylabel("Loss")
ax[0].legend()


ax[1].plot(val_loss_sgd[1::], label='sgd')
ax[1].plot(val_loss_als[1::], label='als')
ax[1].set_title('Validation loss')
ax[1].set_xlabel("Training iteration")
ax[1].set_ylabel("Loss")
ax[1].legend()

plt.show()

# %% [markdown]
# # Autoencoder and t-SNE
#
# Hereinafter, we will implement an autoencoder and analyze its latent space via interpolations and t-SNE. For this, we will use the famous Fashion-MNIST dataset.

# %%
from typing import List

from matplotlib.offsetbox import AnnotationBbox, OffsetImage
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import torchvision
from torchvision.datasets import FashionMNIST
import torch
from torch import nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ExponentialLR

# %% [markdown]
# **Hint:** If you run into memory issues simply reduce the `batch_size`

# %%
train_dataset = FashionMNIST(root='data', download=True, train=True, transform=torchvision.transforms.ToTensor())
test_dataset = FashionMNIST(root='data', download=True, train=False, transform=torchvision.transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1024, shuffle=True, 
                                           num_workers=2, pin_memory=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1024, shuffle=False, 
                                          num_workers=2, pin_memory=True)

# %% [markdown]
# ### Task 4: Define decoder network
#
# Feel free to choose any architecture you like. Our model was this:
# ```
# Autoencoder(
#   (encode): Sequential(
#     (0): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv2d(4, 16, kernel_size=(3, 3), stride=(1, 1))
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): LeakyReLU(negative_slope=0.01)
#     (7): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (11): LeakyReLU(negative_slope=0.01)
#   )
#   (decode): Sequential(
#     (0): ConvTranspose2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), output_padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ConvTranspose2d(16, 16, kernel_size=(3, 3), stride=(2, 2), output_padding=(1, 1))
#     (6): LeakyReLU(negative_slope=0.01)
#     (7): ConvTranspose2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ConvTranspose2d(16, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ConvTranspose2d(4, 1, kernel_size=(3, 3), stride=(1, 1))
#     (10): Sigmoid()
#   )
# )
# ```

# %%
class Autoencoder(nn.Module):
    ## BEGIN SOLUTION

    ## END SOLUTION
    def forward(self, x):
        z = self.encode(x)
        x_approx = self.decode(z)
        
        assert x.shape == x_approx.shape
        return x_approx
    
print(Autoencoder())
# Out:
# Autoencoder(
#   (encode): Sequential(
#     (0): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv2d(4, 16, kernel_size=(3, 3), stride=(1, 1))
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): LeakyReLU(negative_slope=0.01)
#     (7): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (11): LeakyReLU(negative_slope=0.01)
#   )
#   (decode): Sequential(
#     (0): ConvTranspose2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), output_padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ConvTranspose2d(16, 16, kernel_size=(3, 3), stride=(2, 2), output_padding=(1, 1))
#     (6): LeakyReLU(negative_slope=0.01)
#     (7): ConvTranspose2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ConvTranspose2d(16, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ConvTranspose2d(4, 1, kernel_size=(3, 3), stride=(1, 1))
#     (10): Sigmoid()
#   )
# )

# %% [markdown]
# We see that our model transform the image from $28 \cdot 28 = 784$ dimensional space down into a $32 \cdot 3 \cdot 3 = 288$ dimensional space. However, note that the latent space also must contain some spatial information that the decoder needs for decoding.

# %%
x = test_dataset[0][0][None, ...]
z = Autoencoder().encode(x)

print(x.shape)
print(z.shape)
print(Autoencoder().decode(z).shape)
# Out:
# torch.Size([1, 1, 28, 28])
# torch.Size([1, 32, 3, 3])
# torch.Size([1, 1, 28, 28])

# %% [markdown]
# ## Task 5: Train the autoencoder
#
# Of course, we must train the autoencoder if we want to analyze it later on.

# %%
device = 0 if torch.cuda.is_available() else 'cpu'
model = Autoencoder().to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)
scheduler = ExponentialLR(optimizer, gamma=0.999)

log_every_batch = 20

for epoch in range(50):
    model.train()
    train_loss_trace = []
    for batch, (x, _) in enumerate(train_loader):
        # TODO: The autoendocer shall be trained on the mse loss
        ## BEGIN SOLUTION

        ## END SOLUTION
        train_loss_trace.append(loss.detach().item())
        if batch % log_every_batch == 0:
            print(f'Training: Epoch {epoch} batch {batch} - loss {loss}')
    
    model.eval()
    test_loss_trace = []
    for batch, (x, _) in enumerate(test_loader):
        x = x.to(device)
        x_approx = model(x)
        loss = F.mse_loss(x_approx, x)
        test_loss_trace.append(loss.detach().item())
        if batch % log_every_batch == 0:
            print(f'Test: Epoch {epoch} batch {batch} loss {loss}')
    print(f'Epoch {epoch} finished - average train loss {np.mean(train_loss_trace)}, '
          f'average test loss {np.mean(test_loss_trace)}')
# Out:
# Training: Epoch 0 batch 0 - loss 0.1964804232120514
# Training: Epoch 0 batch 20 - loss 0.09351091086864471
# Training: Epoch 0 batch 40 - loss 0.0550072081387043
# Test: Epoch 0 batch 0 loss 0.050341732800006866
# Epoch 0 finished - average train loss 0.08751109375034348, average test loss 0.049865125492215154
# Training: Epoch 1 batch 0 - loss 0.03842395916581154
# Training: Epoch 1 batch 20 - loss 0.03128790855407715
# Training: Epoch 1 batch 40 - loss 0.026680724695324898
# Test: Epoch 1 batch 0 loss 0.024577394127845764
# Epoch 1 finished - average train loss 0.029633777247647108, average test loss 0.02428057212382555
# Training: Epoch 2 batch 0 - loss 0.023424537852406502
# Training: Epoch 2 batch 20 - loss 0.02215844765305519
# Training: Epoch 2 batch 40 - loss 0.020750103518366814
# Test: Epoch 2 batch 0 loss 0.020434269681572914
# Epoch 2 finished - average train loss 0.021771273433657017, average test loss 0.020221901684999467
# Training: Epoch 3 batch 0 - loss 0.019998034462332726
# Training: Epoch 3 batch 20 - loss 0.01936684362590313
# Training: Epoch 3 batch 40 - loss 0.017919758334755898
# Test: Epoch 3 batch 0 loss 0.018434273079037666
# Epoch 3 finished - average train loss 0.01908932326329967, average test loss 0.018215622939169406
# Training: Epoch 4 batch 0 - loss 0.017990561202168465
# Training: Epoch 4 batch 20 - loss 0.01777629181742668
# Training: Epoch 4 batch 40 - loss 0.018010379746556282
# Test: Epoch 4 batch 0 loss 0.017580639570951462
# Epoch 4 finished - average train loss 0.017636639081825643, average test loss 0.017389529012143613
# Training: Epoch 5 batch 0 - loss 0.016845261678099632
# Training: Epoch 5 batch 20 - loss 0.01655660755932331
# Training: Epoch 5 batch 40 - loss 0.016548721119761467
# Test: Epoch 5 batch 0 loss 0.01629934087395668
# Epoch 5 finished - average train loss 0.01657025089834706, average test loss 0.016104038618505002
# Training: Epoch 6 batch 0 - loss 0.01615539751946926
# Training: Epoch 6 batch 20 - loss 0.015570459887385368
# Training: Epoch 6 batch 40 - loss 0.015600893646478653
# Test: Epoch 6 batch 0 loss 0.015444151125848293
# Epoch 6 finished - average train loss 0.01571884127807314, average test loss 0.015282619278877974
# Training: Epoch 7 batch 0 - loss 0.015032072551548481
# Training: Epoch 7 batch 20 - loss 0.014902203343808651
# Training: Epoch 7 batch 40 - loss 0.015123551711440086
# Test: Epoch 7 batch 0 loss 0.015078558586537838
# Epoch 7 finished - average train loss 0.015158997248795074, average test loss 0.01492451848462224
# Training: Epoch 8 batch 0 - loss 0.01466657966375351
# Training: Epoch 8 batch 20 - loss 0.014700441621243954
# Training: Epoch 8 batch 40 - loss 0.014704541303217411
# Test: Epoch 8 batch 0 loss 0.01477865967899561
# Epoch 8 finished - average train loss 0.01465786130057048, average test loss 0.014639007765799761
# Training: Epoch 9 batch 0 - loss 0.014528528787195683
# Training: Epoch 9 batch 20 - loss 0.013852839358150959
# Training: Epoch 9 batch 40 - loss 0.014062277972698212
# Test: Epoch 9 batch 0 loss 0.01422062423080206
# Epoch 9 finished - average train loss 0.014183441871556185, average test loss 0.01408660002052784
# Training: Epoch 10 batch 0 - loss 0.01427899394184351
# Training: Epoch 10 batch 20 - loss 0.014372280798852444
# Training: Epoch 10 batch 40 - loss 0.013542762957513332
# Test: Epoch 10 batch 0 loss 0.014174682088196278
# Epoch 10 finished - average train loss 0.013652217558632463, average test loss 0.014045892655849457
# Training: Epoch 11 batch 0 - loss 0.013694414868950844
# Training: Epoch 11 batch 20 - loss 0.013478935696184635
# Training: Epoch 11 batch 40 - loss 0.013285634107887745
# Test: Epoch 11 batch 0 loss 0.01352735422551632
# Epoch 11 finished - average train loss 0.013340831339611845, average test loss 0.013393245544284582
# Training: Epoch 12 batch 0 - loss 0.012970182113349438
# Training: Epoch 12 batch 20 - loss 0.01294215302914381
# Training: Epoch 12 batch 40 - loss 0.013408416882157326
# Test: Epoch 12 batch 0 loss 0.013350349850952625
# Epoch 12 finished - average train loss 0.013158993906010006, average test loss 0.013233706448227167
# Training: Epoch 13 batch 0 - loss 0.013190758414566517
# Training: Epoch 13 batch 20 - loss 0.012681166641414165
# Training: Epoch 13 batch 40 - loss 0.012766492553055286
# Test: Epoch 13 batch 0 loss 0.013297037221491337
# Epoch 13 finished - average train loss 0.012783140291349363, average test loss 0.013180647697299718
# Training: Epoch 14 batch 0 - loss 0.012805590406060219
# Training: Epoch 14 batch 20 - loss 0.012590602971613407
# Training: Epoch 14 batch 40 - loss 0.013230604119598866
# Test: Epoch 14 batch 0 loss 0.012738714925944805
# Epoch 14 finished - average train loss 0.012462750582371727, average test loss 0.01263012010604143
# Training: Epoch 15 batch 0 - loss 0.012495137751102448
# Training: Epoch 15 batch 20 - loss 0.01252735871821642
# Training: Epoch 15 batch 40 - loss 0.012072375975549221
# Test: Epoch 15 batch 0 loss 0.012581579387187958
# Epoch 15 finished - average train loss 0.012256904694614774, average test loss 0.012464765273034573
# Training: Epoch 16 batch 0 - loss 0.0122150257229805
# Training: Epoch 16 batch 20 - loss 0.012049023061990738
# Training: Epoch 16 batch 40 - loss 0.012330238707363605
# Test: Epoch 16 batch 0 loss 0.012018967419862747
# Epoch 16 finished - average train loss 0.012049571847764113, average test loss 0.011900203861296177
# Training: Epoch 17 batch 0 - loss 0.011805996298789978
# Training: Epoch 17 batch 20 - loss 0.011668477207422256
# Training: Epoch 17 batch 40 - loss 0.012241403572261333
# Test: Epoch 17 batch 0 loss 0.011969344690442085
# Epoch 17 finished - average train loss 0.011833089230171704, average test loss 0.011862778570502996
# Training: Epoch 18 batch 0 - loss 0.011925059370696545
# Training: Epoch 18 batch 20 - loss 0.012141621671617031
# Training: Epoch 18 batch 40 - loss 0.011517258360981941
# Test: Epoch 18 batch 0 loss 0.012802060693502426
# Epoch 18 finished - average train loss 0.011785242438190064, average test loss 0.012696962989866733
# Training: Epoch 19 batch 0 - loss 0.011664451099932194
# Training: Epoch 19 batch 20 - loss 0.011419843882322311
# Training: Epoch 19 batch 40 - loss 0.011742837727069855
# Test: Epoch 19 batch 0 loss 0.012177511118352413
# Epoch 19 finished - average train loss 0.011544321079627943, average test loss 0.012073439080268145
# Training: Epoch 20 batch 0 - loss 0.011184612289071083
# Training: Epoch 20 batch 20 - loss 0.011203663423657417
# Training: Epoch 20 batch 40 - loss 0.011027061380445957
# Test: Epoch 20 batch 0 loss 0.011761067435145378
# Epoch 20 finished - average train loss 0.011467344885281587, average test loss 0.011648547369986773
# Training: Epoch 21 batch 0 - loss 0.011613334529101849
# Training: Epoch 21 batch 20 - loss 0.01121832337230444
# Training: Epoch 21 batch 40 - loss 0.011788985691964626
# Test: Epoch 21 batch 0 loss 0.011525344103574753
# Epoch 21 finished - average train loss 0.011414569139606872, average test loss 0.0113990668207407
# Training: Epoch 22 batch 0 - loss 0.011299780569970608
# Training: Epoch 22 batch 20 - loss 0.011435831896960735
# Training: Epoch 22 batch 40 - loss 0.011011510156095028
# Test: Epoch 22 batch 0 loss 0.011453516781330109
# Epoch 22 finished - average train loss 0.011244021229824777, average test loss 0.011339285410940647
# Training: Epoch 23 batch 0 - loss 0.011156154796481133
# Training: Epoch 23 batch 20 - loss 0.010854797437787056
# Training: Epoch 23 batch 40 - loss 0.011026513762772083
# Test: Epoch 23 batch 0 loss 0.011371096596121788
# Epoch 23 finished - average train loss 0.011134285921767607, average test loss 0.011245610471814872
# Training: Epoch 24 batch 0 - loss 0.010893565602600574
# Training: Epoch 24 batch 20 - loss 0.010975051671266556
# Training: Epoch 24 batch 40 - loss 0.011216433718800545
# Test: Epoch 24 batch 0 loss 0.011563055217266083
# Epoch 24 finished - average train loss 0.011015426004463333, average test loss 0.011457886826246978
# Training: Epoch 25 batch 0 - loss 0.011186547577381134
# Training: Epoch 25 batch 20 - loss 0.010963858105242252
# Training: Epoch 25 batch 40 - loss 0.010905678384006023
# Test: Epoch 25 batch 0 loss 0.010876836255192757
# Epoch 25 finished - average train loss 0.010835320499362582, average test loss 0.0107692233286798
# Training: Epoch 26 batch 0 - loss 0.0105769457295537
# Training: Epoch 26 batch 20 - loss 0.011006291955709457
# Training: Epoch 26 batch 40 - loss 0.010996115393936634
# Test: Epoch 26 batch 0 loss 0.011334344744682312
# Epoch 26 finished - average train loss 0.010829487941780333, average test loss 0.011214904021471739
# Training: Epoch 27 batch 0 - loss 0.01095114927738905
# Training: Epoch 27 batch 20 - loss 0.011022175662219524
# Training: Epoch 27 batch 40 - loss 0.010601798072457314
# Test: Epoch 27 batch 0 loss 0.011202537454664707
# Epoch 27 finished - average train loss 0.010817178193542916, average test loss 0.0110972891561687
# Training: Epoch 28 batch 0 - loss 0.010472690686583519
# Training: Epoch 28 batch 20 - loss 0.010889185592532158
# Training: Epoch 28 batch 40 - loss 0.010569469071924686
# Test: Epoch 28 batch 0 loss 0.01077225711196661
# Epoch 28 finished - average train loss 0.010598775914917558, average test loss 0.01067555034533143
# Training: Epoch 29 batch 0 - loss 0.010609440505504608
# Training: Epoch 29 batch 20 - loss 0.010477632284164429
# Training: Epoch 29 batch 40 - loss 0.010778152383863926
# Test: Epoch 29 batch 0 loss 0.010845543816685677
# Epoch 29 finished - average train loss 0.010640969121102559, average test loss 0.010737022664397956
# Training: Epoch 30 batch 0 - loss 0.01062009483575821
# Training: Epoch 30 batch 20 - loss 0.010577011853456497
# Training: Epoch 30 batch 40 - loss 0.010449299588799477
# Test: Epoch 30 batch 0 loss 0.010552209801971912
# Epoch 30 finished - average train loss 0.010565677973425995, average test loss 0.01044821348041296
# Training: Epoch 31 batch 0 - loss 0.010153130628168583
# Training: Epoch 31 batch 20 - loss 0.010606884956359863
# Training: Epoch 31 batch 40 - loss 0.010203892365098
# Test: Epoch 31 batch 0 loss 0.010517160408198833
# Epoch 31 finished - average train loss 0.010402030579872051, average test loss 0.010404302179813385
# Training: Epoch 32 batch 0 - loss 0.010327070951461792
# Training: Epoch 32 batch 20 - loss 0.010260173119604588
# Training: Epoch 32 batch 40 - loss 0.010398761369287968
# Test: Epoch 32 batch 0 loss 0.01056844461709261
# Epoch 32 finished - average train loss 0.010399292680924222, average test loss 0.010473472531884909
# Training: Epoch 33 batch 0 - loss 0.010479241609573364
# Training: Epoch 33 batch 20 - loss 0.010475914925336838
# Training: Epoch 33 batch 40 - loss 0.009930016472935677
# Test: Epoch 33 batch 0 loss 0.01073451992124319
# Epoch 33 finished - average train loss 0.01028862843384682, average test loss 0.010645543597638607
# Training: Epoch 34 batch 0 - loss 0.01043280865997076
# Training: Epoch 34 batch 20 - loss 0.009988942183554173
# Training: Epoch 34 batch 40 - loss 0.010399962775409222
# Test: Epoch 34 batch 0 loss 0.010633924975991249
# Epoch 34 finished - average train loss 0.010336767345414324, average test loss 0.010536077804863453
# Training: Epoch 35 batch 0 - loss 0.010569581761956215
# Training: Epoch 35 batch 20 - loss 0.009808961302042007
# Training: Epoch 35 batch 40 - loss 0.010247230529785156
# Test: Epoch 35 batch 0 loss 0.01027038972824812
# Epoch 35 finished - average train loss 0.010252261660614256, average test loss 0.010169800277799368
# Training: Epoch 36 batch 0 - loss 0.009871934540569782
# Training: Epoch 36 batch 20 - loss 0.009899401105940342
# Training: Epoch 36 batch 40 - loss 0.009774874895811081
# Test: Epoch 36 batch 0 loss 0.01057970616966486
# Epoch 36 finished - average train loss 0.010066855446261874, average test loss 0.010488031432032585
# Training: Epoch 37 batch 0 - loss 0.010533314198255539
# Training: Epoch 37 batch 20 - loss 0.010105196386575699
# Training: Epoch 37 batch 40 - loss 0.009990982711315155
# Test: Epoch 37 batch 0 loss 0.01008346676826477
# Epoch 37 finished - average train loss 0.010156629985924495, average test loss 0.009981524664908648
# Training: Epoch 38 batch 0 - loss 0.00967983715236187
# Training: Epoch 38 batch 20 - loss 0.010141248814761639
# Training: Epoch 38 batch 40 - loss 0.009857002645730972
# Test: Epoch 38 batch 0 loss 0.010238975286483765
# Epoch 38 finished - average train loss 0.010117811845394514, average test loss 0.010125655680894852
# Training: Epoch 39 batch 0 - loss 0.009862943552434444
# Training: Epoch 39 batch 20 - loss 0.010036981664597988
# Training: Epoch 39 batch 40 - loss 0.009906936436891556
# Test: Epoch 39 batch 0 loss 0.01026065368205309
# Epoch 39 finished - average train loss 0.00993482973742283, average test loss 0.010154691524803638
# Training: Epoch 40 batch 0 - loss 0.009550550021231174
# Training: Epoch 40 batch 20 - loss 0.009821471758186817
# Training: Epoch 40 batch 40 - loss 0.01013107132166624
# Test: Epoch 40 batch 0 loss 0.010207537561655045
# Epoch 40 finished - average train loss 0.009911717783849118, average test loss 0.010101174656301736
# Training: Epoch 41 batch 0 - loss 0.00994561705738306
# Training: Epoch 41 batch 20 - loss 0.009954886510968208
# Training: Epoch 41 batch 40 - loss 0.009967315010726452
# Test: Epoch 41 batch 0 loss 0.010219619609415531
# Epoch 41 finished - average train loss 0.009892944435952074, average test loss 0.01011574761942029
# Training: Epoch 42 batch 0 - loss 0.010194312781095505
# Training: Epoch 42 batch 20 - loss 0.010086515918374062
# Training: Epoch 42 batch 40 - loss 0.01016323920339346
# Test: Epoch 42 batch 0 loss 0.010014825500547886
# Epoch 42 finished - average train loss 0.009817695797626244, average test loss 0.009912188816815614
# Training: Epoch 43 batch 0 - loss 0.00961337797343731
# Training: Epoch 43 batch 20 - loss 0.009711608290672302
# Training: Epoch 43 batch 40 - loss 0.009738050401210785
# Test: Epoch 43 batch 0 loss 0.009977304376661777
# Epoch 43 finished - average train loss 0.009828412700128757, average test loss 0.00986904501914978
# Training: Epoch 44 batch 0 - loss 0.00953340157866478
# Training: Epoch 44 batch 20 - loss 0.01004618126899004
# Training: Epoch 44 batch 40 - loss 0.009667817503213882
# Test: Epoch 44 batch 0 loss 0.010212880559265614
# Epoch 44 finished - average train loss 0.009802959464742975, average test loss 0.010108277201652527
# Training: Epoch 45 batch 0 - loss 0.009881927631795406
# Training: Epoch 45 batch 20 - loss 0.009543080814182758
# Training: Epoch 45 batch 40 - loss 0.009946556761860847
# Test: Epoch 45 batch 0 loss 0.009864536114037037
# Epoch 45 finished - average train loss 0.009754836085741804, average test loss 0.009757693763822317
# Training: Epoch 46 batch 0 - loss 0.009647543542087078
# Training: Epoch 46 batch 20 - loss 0.00991777703166008
# Training: Epoch 46 batch 40 - loss 0.009289517998695374
# Test: Epoch 46 batch 0 loss 0.010321962647140026
# Epoch 46 finished - average train loss 0.009742817809899985, average test loss 0.010212868358939886
# Training: Epoch 47 batch 0 - loss 0.009803765453398228
# Training: Epoch 47 batch 20 - loss 0.00948354136198759
# Training: Epoch 47 batch 40 - loss 0.009242258965969086
# Test: Epoch 47 batch 0 loss 0.010154964402318
# Epoch 47 finished - average train loss 0.009628795939734426, average test loss 0.01005165111273527
# Training: Epoch 48 batch 0 - loss 0.009668517857789993
# Training: Epoch 48 batch 20 - loss 0.009521818719804287
# Training: Epoch 48 batch 40 - loss 0.010094930417835712
# Test: Epoch 48 batch 0 loss 0.01092435885220766
# Epoch 48 finished - average train loss 0.009646440240538727, average test loss 0.010820469167083503
# Training: Epoch 49 batch 0 - loss 0.009734689258038998
# Training: Epoch 49 batch 20 - loss 0.009956405498087406
# Training: Epoch 49 batch 40 - loss 0.010120020247995853
# Test: Epoch 49 batch 0 loss 0.010265386663377285
# Epoch 49 finished - average train loss 0.009748300932095213, average test loss 0.010146952699869871

# %%
model.eval()
with torch.no_grad():
    latent = []
    for batch, (x, _) in enumerate(test_loader):
        latent.append(model.encode(x.to(device)).cpu())
    latent = torch.cat(latent)

# %% [markdown]
# ## PCA and t-SNE (nothing to do here)
# Next, we are going to look at some random images and their embeddings. Since 7x7 is still too large to visialize further dimensionality reduction techniques are required.
#
# It is not uncommand that a neural network designer wants to understand whats going on in the latent space and therefore uses techniques such as t-SNE.

# %%
def plot_latent(test_dataset: torch.utils.data.Dataset, z_test: torch.Tensor, count: int, 
                technique: str, perplexity: float = 30):
    """
    Fit t-SNE or PCA and plots the latent space. Moreover, we then display the correspeondig image.
    
    Parameters
    ----------
    test_dataset  : torch.utils.data.DataSet
                    Dataset containing raw images to display.
    z_test        : torch.Tensor
                    The transformed images.
    count         : int
                    Number of random images to sample
    technique     : str
                    Either "pca" or "tsne". Otherwise, a ValueError is thrown.
    perplexity    : float, optional, default: 30.0
                    Perplexity is t-SNE is used.
        
    """
    indices = np.random.choice(len(z_test), count, replace=False)
    inputs = z_test[indices]
    fig, ax = plt.subplots(figsize=(10, 7))
    ax.set_title(technique)
    if technique == 'pca':
        coords = PCA(n_components=2).fit_transform(inputs.reshape(count, -1))
    elif technique == 'tsne':
        coords = TSNE(n_components=2, perplexity=perplexity).fit_transform(inputs.reshape(count, -1))
    else:
        raise ValueError()

    for idx, (x, y) in zip(indices, coords):
        im = OffsetImage(test_dataset[idx][0].squeeze().numpy(), zoom=1, cmap='gray')
        ab = AnnotationBbox(im, (x, y), xycoords='data', frameon=False)
        ax.add_artist(ab)
    ax.update_datalim(coords)
    ax.autoscale()
    plt.show()

# %%
plot_latent(test_dataset, latent, 1000, 'pca')

# %%
plot_latent(test_dataset, latent, 300, 'tsne', perplexity=5)

# %%
plot_latent(test_dataset, latent, 300, 'tsne', perplexity=10)

# %%
plot_latent(test_dataset, latent, 300, 'tsne', perplexity=30)

# %%
plot_latent(test_dataset, latent, 300, 'tsne', perplexity=50)

# %%
plot_latent(test_dataset, latent, 300, 'tsne', perplexity=150)

# %% [markdown]
# ## Task 6: Linear Interpolation on the latent space
# If the latent space has learned something meanigfull, we can leverage this for further analysis/downstream tasks. Anyways, we were wondering all along how the interpolation between a shoe and a pullover might look like.
#
# For this we encode two images $z_i = f_{enc}(x_i)$ and $z_j = f_{enc}(x_j)$. Then we linearily interpolate $k$ equidistant locations on the line between $z_i$ and $z_j$. Those locations are then be decooded by the decoder network $f_{dec}(\dots)$.

# %%
def interpolate_between(model: Autoencoder, test_dataset: torch.utils.data.Dataset, idx_i: int, idx_j: int, n = 12):
    """
    Plot original images and the reconstruction of the linear interpolation in the respective latent space embedding.
    
    Parameters
    ----------
    model         : Autoencoder
                    The (trained) autoencoder.
    test_dataset  : torch.utils.data.Dataset
                    Test images.
    idx_i         : int
                    Id for first image.
    idx_j         : int
                    Id for second image.
    n             : n, optional, default: 1
                    Number of intermediate interoplations (including original reconstructions).
        
    """
    fig, ax = plt.subplots(1, 2, figsize=[6, 4])
    fig.suptitle("Original images")
    ax[0].imshow(test_dataset[idx_i][0][0].numpy(), cmap='gray')
    ax[1].imshow(test_dataset[idx_j][0][0].numpy(), cmap='gray')
    
    # Get embedding
    z_i = model.encode(test_dataset[idx_i][0].to(device)[None, ...])[0]
    z_j = model.encode(test_dataset[idx_j][0].to(device)[None, ...])[0]
    
    fig, ax = plt.subplots(2, n//2, figsize=[15, 8])
    ax = [sub for row in ax for sub in row]
    fig.suptitle("Reconstruction after interpolation in latent space")

    with torch.no_grad():
        # TODO: Linearily interpolate between `z_i` and `z_j` in `n` equidistant steps. 
        # Then decode the embedding and plot the image and add the percentage as a title.
        ## BEGIN SOLUTION

        ## END SOLUTION

    plt.show()

# %%
interpolate_between(model, test_dataset, 0, 1)

# %%
interpolate_between(model, test_dataset, 2, 4)

# %%
interpolate_between(model, test_dataset, 100, 200)
